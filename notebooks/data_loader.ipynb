# %%
import sys
sys.path.append('..')

# %%
from src.load_comments import YouTubeCommentLoader
from dotenv import load_dotenv
import os 

load_dotenv()
api_key = os.getenv("API_KEY")

# %%
loader = YouTubeCommentLoader(api_key=api_key)
video_url = "https://www.youtube.com/watch?v=5oJq8CVoHBw"
all_comments_df = loader.get_all_comments(video_url)
# Out:
# Retrieving ALL comments for video: https://www.youtube.com/watch?v=5oJq8CVoHBw
# Video ID: 5oJq8CVoHBw
# Fetched batch of 100 comments. Total: 100
# Fetched batch of 100 comments. Total: 200
# Fetched batch of 46 comments. Total: 246
# No more comments available.
# Retrieved 246 comments in total for video 5oJq8CVoHBw

# %%
all_comments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   comment_id         246 non-null    object
#  1   author             246 non-null    object
#  2   author_channel_id  246 non-null    object
#  3   text               246 non-null    object
#  4   like_count         246 non-null    int64
#  5   published_at       246 non-null    object
#  6   updated_at         246 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 13.6+ KB

# %%
all_comments_df.sort_values('like_count', ascending = False).head(20)
# Out:
#                      comment_id                      author  \
# 203  UgxitZ3d7LaNqiVMajp4AaABAg                     @Mdb_24
# 235  UgxINPMj1sErCWNI1v54AaABAg                @v.prashanth
# 199  UgzSRXN1jsWroaAo2Sl4AaABAg                 @techknacks
# 186  Ugy1APJ-7iWoZb9CkVl4AaABAg           @jeffmurphree2937
# 121  UgwHKgisvUO8dZLYLEl4AaABAg           @emilyverdoza2571
# 242  UgyNCqf-MrLHfiipfKh4AaABAg                   @PB111627
# 196  Ugx7JOLfq8swuvgiF6Z4AaABAg               @1042firegirl
# 154  UgzyoIOGU8XTktXMjoB4AaABAg            @wesleywhite3561
# 227  Ugysi1CMjCTPTrw54PJ4AaABAg  @embodiedentertainment8712
# 139  UgwZicGPgklp9tDUgAB4AaABAg                 @JaysonPSNZ
# 149  UgzuvZFfPpQ3uWb7BEh4AaABAg         @melissaperkins8910
# 239  UgzHOUnpvh2c0SWdmDN4AaABAg               @Thomas-hl5mp
# 187  Ugx_pBGsjco0vaLvGo94AaABAg                 @1101G12646
# 217  UgwPHGxLeHVd4_dcZal4AaABAg        @adriennestephens794
# 153  UgwTBpdjQ7Gu8xoG0u94AaABAg                 @tjeddy3052
# ...

# %%
all_comments_df.to_csv(r'data\raw\raw_data_vertuo_pop.csv', index=False)
